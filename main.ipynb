# %%
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

# %%
num_to_class = {
    0: "Human-written text",
    1: "DeepSeek generated text",
    2: "Grok generated text",
    3: "Claude generated text",
    4: "Gemini generated text",
    5: "ChatGPT generated text"
}

# %%
X_df = pd.read_csv("./dataset/train.csv")
X_df
# Out:
#                                                    TEXT  LABEL
# 0     Dear state senator, There should be a change i...      0
# 1     A star's life cycle begins in a nebula and pro...      1
# 2     Limiting the usage of has a variety advantages...      0
# 3     Biodiversity loss accelerates at unprecedented...      3
# 4     The morning had been cold. The hours dawn stil...      0
# ...                                                 ...    ...
# 2395  The study of biotechnology involves the use of...      5
# 2396  The Maya's advanced astronomical knowledge was...      1
# 2397  When each person drives a dieseltussling car, ...      0
# 2398  The delicate art of origami transforms a flat ...      1
# 2399  Proper succulent maintenance includes avoiding...      2
#
# [2400 rows x 2 columns]

# %%
X_df["LABEL"].value_counts().plot(kind="bar")
X_df["LABEL"].value_counts()
# Out:
# LABEL
# 0    1520
# 5     320
# 4     240
# 2     160
# 1      80
# 3      80
# Name: count, dtype: int64
